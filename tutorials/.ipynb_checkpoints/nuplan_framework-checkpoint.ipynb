# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | ~1200h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
LOG_DIR = str(SAVE_DIR / EXPERIMENT)

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
    # 'splitter=nuplan',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {LOG_DIR}
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 15083), started 0:00:43 ago. (Use '!kill 15083' to kill it.)
#       <iframe id="tensorboard-frame-629f6fbed82c07cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-629f6fbed82c07cd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:33, in env(key, default)
#      32 try:
# ---> 33     return os.environ[key]
#      34 except KeyError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'NUPLAN_MAPS_ROOT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 if hasattr( visitor, "visitConfigValue" ):
# --> 205     return visitor.visitConfigValue(self)
#     206 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#     100 assert ctx.getChildCount() == 2
# --> 101 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     338 if hasattr( visitor, "visitText" ):
# --> 339     return visitor.visitText(self)
#     340 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     124 assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1029 if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030     return visitor.visitInterpolationResolver(self)
#    1031 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# KeyError: "Environment variable 'NUPLAN_MAPS_ROOT' not found"
#
# During handling of the above exception, another exception occurred:
#
# InterpolationResolutionError              Traceback (most recent call last)
# Cell In[10], line 4
#       1 from nuplan.planning.script.run_training import main as main_train
#       3 # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
# ----> 4 main_train(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_training.py:47, in main(cfg)
#      44 build_logger(cfg)
#      46 # Override configs based on setup, and print config
# ---> 47 update_config_for_training(cfg)
#      49 # Create output storage folder
#      50 build_training_experiment_folder(cfg=cfg)
#
# File ~/nuplan-devkit/nuplan/planning/script/builders/utils/utils_config.py:48, in update_config_for_training(cfg)
#      45     cfg.lightning.trainer.params.precision = 32
#      47 # Save all interpolations and remove keys that were only used for interpolation and have no further use.
# ---> 48 OmegaConf.resolve(cfg)
#      50 # Finalize the configuration and make it non-editable.
#      51 OmegaConf.set_struct(cfg, True)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:786, in OmegaConf.resolve(cfg)
#     780 if not OmegaConf.is_config(cfg):
#     781     # Since this function is mutating the input object in-place, it doesn't make sense to
#     782     # auto-convert the input object to an OmegaConf container
#     783     raise ValueError(
#     784         f"Invalid config type ({type(cfg).__name__}), expected an OmegaConf Container"
#     785     )
# --> 786 omegaconf._impl._resolve(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:25, in _resolve_container_value(cfg, key)
#      23             node._set_value(resolved._value())
#      24 else:
# ---> 25     _resolve(node)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:14, in _resolve_container_value(cfg, key)
#      12 if node._is_interpolation():
#      13     try:
# ---> 14         resolved = node._dereference_node()
#      15     except InterpolationToMissingValueError:
#      16         node._set_value(MISSING)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:205, in Node._dereference_node(self)
#     204 def _dereference_node(self) -> "Node":
# --> 205     node = self._dereference_node_impl(throw_on_resolution_failure=True)
#     206     assert node is not None
#     207     return node
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:236, in Node._dereference_node_impl(self, throw_on_resolution_failure, memo)
#     234 assert parent is not None
#     235 key = self._key()
# --> 236 return parent._resolve_interpolation_from_parse_tree(
#     237     parent=parent,
#     238     key=key,
#     239     value=self,
#     240     parse_tree=parse(_get_value(self)),
#     241     throw_on_resolution_failure=throw_on_resolution_failure,
#     242     memo=memo,
#     243 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:482, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     452 """
#     453 Resolve an interpolation.
#     454
#    (...)
#     478     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     479 """
#     481 try:
# --> 482     resolved = self.resolve_parse_tree(
#     483         parse_tree=parse_tree, node=value, key=key, parent=parent, memo=memo
#     484     )
#     485 except InterpolationResolutionError:
#     486     if throw_on_resolution_failure:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:667, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     664     raise
#     665 except Exception as exc:
#     666     # Other kinds of exceptions are wrapped in an `InterpolationResolutionError`.
# --> 667     raise InterpolationResolutionError(
#     668         f"{type(exc).__name__} raised while resolving interpolation: {exc}"
#     669     ).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     656 visitor = GrammarVisitor(
#     657     node_interpolation_callback=node_interpolation_callback,
#     658     resolver_interpolation_callback=resolver_interpolation_callback,
#     659     memo=memo,
#     660 )
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#     664     raise
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     203 def accept(self, visitor:ParseTreeVisitor):
#     204     if hasattr( visitor, "visitConfigValue" ):
# --> 205         return visitor.visitConfigValue(self)
#     206     else:
#     207         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     337 def accept(self, visitor:ParseTreeVisitor):
#     338     if hasattr( visitor, "visitText" ):
# --> 339         return visitor.visitText(self)
#     340     else:
#     341         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     296     c = ctx.getChild(0)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#     301 return self._unescape(list(ctx.getChildren()))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1028 def accept(self, visitor:ParseTreeVisitor):
#    1029     if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030         return visitor.visitInterpolationResolver(self)
#    1031     else:
#    1032         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     176         args.append(val)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     589 if resolver is not None:
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#     599     raise UnsupportedInterpolationType(
#     600         f"Unsupported interpolation type {inter_type}"
#     601     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     432 if pass_root:
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#     438     cache[args_str] = ret
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      36     return str(default) if default is not None else None
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# InterpolationResolutionError: KeyError raised while resolving interpolation: "Environment variable 'NUPLAN_MAPS_ROOT' not found"

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook) Figure-> figure in metric_summary_callback.py 19

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-02-20 14:29:24,292 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-20 14:29:24,292 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-20 14:29:24,369 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-02-20 14:29:24,369 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:33, in env(key, default)
#      32 try:
# ---> 33     return os.environ[key]
#      34 except KeyError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'NUPLAN_MAPS_ROOT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 if hasattr( visitor, "visitConfigValue" ):
# --> 205     return visitor.visitConfigValue(self)
#     206 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#     100 assert ctx.getChildCount() == 2
# --> 101 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     338 if hasattr( visitor, "visitText" ):
# --> 339     return visitor.visitText(self)
#     340 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     124 assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1029 if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030     return visitor.visitInterpolationResolver(self)
#    1031 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# KeyError: "Environment variable 'NUPLAN_MAPS_ROOT' not found"
#
# During handling of the above exception, another exception occurred:
#
# InterpolationResolutionError              Traceback (most recent call last)
# Cell In[17], line 4
#       1 from nuplan.planning.script.run_simulation import main as main_simulation
#       3 # Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
# ----> 4 main_simulation(cfg)
#       6 # Simple simulation folder for visualization in nuBoard
#       7 simple_simulation_folder = cfg.output_dir
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_simulation.py:96, in main(cfg)
#      93 assert cfg.simulation_log_main_path is None, 'Simulation_log_main_path must not be set when running simulation.'
#      95 # Execute simulation with preconfigured planner(s).
# ---> 96 run_simulation(cfg=cfg)
#
# File ~/nuplan-devkit/nuplan/planning/script/run_simulation.py:47, in run_simulation(cfg, planners)
#      44 pl.seed_everything(cfg.seed, workers=True)
#      46 profiler_name = 'building_simulation'
# ---> 47 common_builder = set_up_common_builder(cfg=cfg, profiler_name=profiler_name)
#      49 # Build scenario builder
#      50 scenario_builder = build_scenario_builder(cfg=cfg)
#
# File ~/nuplan-devkit/nuplan/planning/script/utils.py:88, in set_up_common_builder(cfg, profiler_name)
#      85 multi_main_callback.on_run_simulation_start()
#      87 # Update and override configs for simulation
# ---> 88 update_config_for_simulation(cfg=cfg)
#      90 # Configure logger
#      91 build_logger(cfg)
#
# File ~/nuplan-devkit/nuplan/planning/script/builders/utils/utils_config.py:72, in update_config_for_simulation(cfg)
#      69     cfg.callbacks = [callback for callback in cfg.callback.values() if not is_target_type(callback, TimingCallback)]
#      71 # Save all interpolations and remove keys that were only used for interpolation and have no further use.
# ---> 72 OmegaConf.resolve(cfg)
#      74 # Finalize the configuration and make it non-editable.
#      75 OmegaConf.set_struct(cfg, True)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:786, in OmegaConf.resolve(cfg)
#     780 if not OmegaConf.is_config(cfg):
#     781     # Since this function is mutating the input object in-place, it doesn't make sense to
#     782     # auto-convert the input object to an OmegaConf container
#     783     raise ValueError(
#     784         f"Invalid config type ({type(cfg).__name__}), expected an OmegaConf Container"
#     785     )
# --> 786 omegaconf._impl._resolve(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:25, in _resolve_container_value(cfg, key)
#      23             node._set_value(resolved._value())
#      24 else:
# ---> 25     _resolve(node)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:14, in _resolve_container_value(cfg, key)
#      12 if node._is_interpolation():
#      13     try:
# ---> 14         resolved = node._dereference_node()
#      15     except InterpolationToMissingValueError:
#      16         node._set_value(MISSING)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:205, in Node._dereference_node(self)
#     204 def _dereference_node(self) -> "Node":
# --> 205     node = self._dereference_node_impl(throw_on_resolution_failure=True)
#     206     assert node is not None
#     207     return node
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:236, in Node._dereference_node_impl(self, throw_on_resolution_failure, memo)
#     234 assert parent is not None
#     235 key = self._key()
# --> 236 return parent._resolve_interpolation_from_parse_tree(
#     237     parent=parent,
#     238     key=key,
#     239     value=self,
#     240     parse_tree=parse(_get_value(self)),
#     241     throw_on_resolution_failure=throw_on_resolution_failure,
#     242     memo=memo,
#     243 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:482, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     452 """
#     453 Resolve an interpolation.
#     454
#    (...)
#     478     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     479 """
#     481 try:
# --> 482     resolved = self.resolve_parse_tree(
#     483         parse_tree=parse_tree, node=value, key=key, parent=parent, memo=memo
#     484     )
#     485 except InterpolationResolutionError:
#     486     if throw_on_resolution_failure:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:667, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     664     raise
#     665 except Exception as exc:
#     666     # Other kinds of exceptions are wrapped in an `InterpolationResolutionError`.
# --> 667     raise InterpolationResolutionError(
#     668         f"{type(exc).__name__} raised while resolving interpolation: {exc}"
#     669     ).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     656 visitor = GrammarVisitor(
#     657     node_interpolation_callback=node_interpolation_callback,
#     658     resolver_interpolation_callback=resolver_interpolation_callback,
#     659     memo=memo,
#     660 )
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#     664     raise
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     203 def accept(self, visitor:ParseTreeVisitor):
#     204     if hasattr( visitor, "visitConfigValue" ):
# --> 205         return visitor.visitConfigValue(self)
#     206     else:
#     207         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     337 def accept(self, visitor:ParseTreeVisitor):
#     338     if hasattr( visitor, "visitText" ):
# --> 339         return visitor.visitText(self)
#     340     else:
#     341         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     296     c = ctx.getChild(0)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#     301 return self._unescape(list(ctx.getChildren()))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1028 def accept(self, visitor:ParseTreeVisitor):
#    1029     if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030         return visitor.visitInterpolationResolver(self)
#    1031     else:
#    1032         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     176         args.append(val)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     589 if resolver is not None:
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#     599     raise UnsupportedInterpolationType(
#     600         f"Unsupported interpolation type {inter_type}"
#     601     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     432 if pass_root:
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#     438     cache[args_str] = ret
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      36     return str(default) if default is not None else None
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# InterpolationResolutionError: KeyError raised while resolving interpolation: "Environment variable 'NUPLAN_MAPS_ROOT' not found"

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(Path(LOG_DIR).iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-01-10 19:31:56,287 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-01-10 19:31:56,306 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-01-10 19:31:56,409 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-01-10 19:31:56,409 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-01-10 19:31:56,410 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-01-10 19:31:56,410 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-01-10 19:31:58,586 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-01-10 19:31:58,586 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-01-10 19:32:00,505	INFO worker.py:1538 -- Started a local Ray instance.
# 2023-01-10 19:32:01,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-01-10 19:32:01,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.01.10.19.31.56
#
# 2023-01-10 19:32:01,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.01.10.19.31.56
#
# 2023-01-10 19:32:01,396 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-01-10 19:32:01,396 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-01-10 19:32:01,396 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-01-10 19:32:01,396 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-01-10 19:32:01,402 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-01-10 19:32:01,402 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-01-10 19:32:01,403 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-01-10 19:32:01,404 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-01-10 19:32:01,404 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-01-10 19:32:01,404 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-01-10 19:32:01,404 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# Ray objects:   0%|          | 0/24 [00:00<?, ?it/s](pid=143043) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143043)
# (pid=143043) import os
# (pid=143043) os.environ['USE_PYGEOS'] = '0'
# (pid=143043) import geopandas
# (pid=143043)
# (pid=143043) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143043)   import geopandas as gpd  # noqa: E402
# (pid=143038) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143038)
# (pid=143038) import os
# (pid=143038) os.environ['USE_PYGEOS'] = '0'
# (pid=143038) import geopandas
# (pid=143038)
# (pid=143038) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143038)   import geopandas as gpd  # noqa: E402
# (pid=143029) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143029)
# (pid=143029) import os
# (pid=143029) os.environ['USE_PYGEOS'] = '0'
# (pid=143029) import geopandas
# (pid=143029)
# (pid=143029) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143029)   import geopandas as gpd  # noqa: E402
# (pid=143028) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143028)
# (pid=143028) import os
# (pid=143028) os.environ['USE_PYGEOS'] = '0'
# (pid=143028) import geopandas
# (pid=143028)
# (pid=143028) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143028)   import geopandas as gpd  # noqa: E402
# (pid=143032) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143032)
# (pid=143032) import os
# (pid=143032) os.environ['USE_PYGEOS'] = '0'
# (pid=143032) import geopandas
# (pid=143032)
# (pid=143032) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143032)   import geopandas as gpd  # noqa: E402
# (pid=143050) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143050)
# (pid=143050) import os
# (pid=143050) os.environ['USE_PYGEOS'] = '0'
# (pid=143050) import geopandas
# (pid=143050)
# (pid=143050) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143050)   import geopandas as gpd  # noqa: E402
# (pid=143042) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143042)
# (pid=143042) import os
# (pid=143042) os.environ['USE_PYGEOS'] = '0'
# (pid=143042) import geopandas
# (pid=143042)
# (pid=143042) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143042)   import geopandas as gpd  # noqa: E402
# (pid=143036) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143036)
# (pid=143036) import os
# (pid=143036) os.environ['USE_PYGEOS'] = '0'
# (pid=143036) import geopandas
# (pid=143036)
# (pid=143036) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143036)   import geopandas as gpd  # noqa: E402
# (pid=143051) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143051)
# (pid=143051) import os
# (pid=143051) os.environ['USE_PYGEOS'] = '0'
# (pid=143051) import geopandas
# (pid=143051)
# (pid=143051) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143051)   import geopandas as gpd  # noqa: E402
# (pid=143040) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143040)
# (pid=143040) import os
# (pid=143040) os.environ['USE_PYGEOS'] = '0'
# (pid=143040) import geopandas
# (pid=143040)
# (pid=143040) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143040)   import geopandas as gpd  # noqa: E402
# (pid=143045) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143045)
# (pid=143045) import os
# (pid=143045) os.environ['USE_PYGEOS'] = '0'
# (pid=143045) import geopandas
# (pid=143045)
# (pid=143045) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143045)   import geopandas as gpd  # noqa: E402
# (pid=143044) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143044)
# (pid=143044) import os
# (pid=143044) os.environ['USE_PYGEOS'] = '0'
# (pid=143044) import geopandas
# (pid=143044)
# (pid=143044) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143044)   import geopandas as gpd  # noqa: E402
# (pid=143047) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143047)
# (pid=143047) import os
# (pid=143047) os.environ['USE_PYGEOS'] = '0'
# (pid=143047) import geopandas
# (pid=143047)
# (pid=143047) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143047)   import geopandas as gpd  # noqa: E402
# (pid=143041) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143041)
# (pid=143041) import os
# (pid=143041) os.environ['USE_PYGEOS'] = '0'
# (pid=143041) import geopandas
# (pid=143041)
# (pid=143041) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143041)   import geopandas as gpd  # noqa: E402
# (pid=143031) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143031)
# (pid=143031) import os
# (pid=143031) os.environ['USE_PYGEOS'] = '0'
# (pid=143031) import geopandas
# (pid=143031)
# (pid=143031) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143031)   import geopandas as gpd  # noqa: E402
# (pid=143048) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143048)
# (pid=143048) import os
# (pid=143048) os.environ['USE_PYGEOS'] = '0'
# (pid=143048) import geopandas
# (pid=143048)
# (pid=143048) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143048)   import geopandas as gpd  # noqa: E402
# (pid=143035) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143035)
# (pid=143035) import os
# (pid=143035) os.environ['USE_PYGEOS'] = '0'
# (pid=143035) import geopandas
# (pid=143035)
# (pid=143035) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143035)   import geopandas as gpd  # noqa: E402
# (pid=143037) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143037)
# (pid=143037) import os
# (pid=143037) os.environ['USE_PYGEOS'] = '0'
# (pid=143037) import geopandas
# (pid=143037)
# (pid=143037) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143037)   import geopandas as gpd  # noqa: E402
# (pid=143046) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143046)
# (pid=143046) import os
# (pid=143046) os.environ['USE_PYGEOS'] = '0'
# (pid=143046) import geopandas
# (pid=143046)
# (pid=143046) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143046)   import geopandas as gpd  # noqa: E402
# (pid=143052) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143052)
# (pid=143052) import os
# (pid=143052) os.environ['USE_PYGEOS'] = '0'
# (pid=143052) import geopandas
# (pid=143052)
# (pid=143052) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143052)   import geopandas as gpd  # noqa: E402
# (pid=143033) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143033)
# (pid=143033) import os
# (pid=143033) os.environ['USE_PYGEOS'] = '0'
# (pid=143033) import geopandas
# (pid=143033)
# (pid=143033) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143033)   import geopandas as gpd  # noqa: E402
# (pid=143030) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143030)
# (pid=143030) import os
# (pid=143030) os.environ['USE_PYGEOS'] = '0'
# (pid=143030) import geopandas
# (pid=143030)
# (pid=143030) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143030)   import geopandas as gpd  # noqa: E402
# (pid=143034) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143034)
# (pid=143034) import os
# (pid=143034) os.environ['USE_PYGEOS'] = '0'
# (pid=143034) import geopandas
# (pid=143034)
# (pid=143034) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143034)   import geopandas as gpd  # noqa: E402
# (pid=143039) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=143039)
# (pid=143039) import os
# (pid=143039) os.environ['USE_PYGEOS'] = '0'
# (pid=143039) import geopandas
# (pid=143039)
# (pid=143039) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=143039)   import geopandas as gpd  # noqa: E402
# Ray objects: 100%|██████████| 24/24 [00:01<00:00, 12.51it/s]
# 2023-01-10 19:32:03,341 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-01-10 19:32:03,341 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-01-10 19:32:03,342 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-01-10 19:32:03,342 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:03,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:03,488 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:03,488 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:03,539 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:03,539 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:03,554 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:03,554 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:03,700 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:03,700 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:03,821 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:03,821 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:03,839 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:03,839 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:03,852 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:03,852 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:04,150 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,150 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,266 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:04,266 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:04,288 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:04,288 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:04,301 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:04,301 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:04,585 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,585 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,721 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:04,721 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:04,739 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:04,739 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:04,754 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:04,754 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:04,878 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,878 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:04,996 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:04,996 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:05,017 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,017 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,030 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:05,030 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:05,335 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:05,335 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:05,452 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:05,452 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:05,469 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,469 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,483 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:05,483 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:05,763 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:05,763 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:05,880 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:05,880 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:05,901 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,901 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:05,914 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:05,914 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:06,046 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:06,046 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:06,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:06,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:06,181 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:06,181 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:06,194 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:06,194 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:06,494 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:06,494 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:06,611 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:06,611 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:06,631 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:06,631 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:06,645 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:06,645 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:06,965 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:06,965 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,085 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,085 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,102 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,102 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,116 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,116 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,238 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,238 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,359 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,359 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,381 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,381 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,705 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,705 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,821 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,821 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:07,838 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,838 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:07,851 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,851 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:07,973 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:07,973 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-01-10 19:32:08,092 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:08,092 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-01-10 19:32:08,282 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:08,282 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-01-10 19:32:08,295 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-01-10 19:32:08,295 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# ...
# (pid=146576)
# (pid=146576) import os
# (pid=146576) os.environ['USE_PYGEOS'] = '0'
# (pid=146576) import geopandas
# (pid=146576)
# (pid=146576) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146576)   import geopandas as gpd  # noqa: E402
# (pid=146627) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146627)
# (pid=146627) import os
# (pid=146627) os.environ['USE_PYGEOS'] = '0'
# (pid=146627) import geopandas
# (pid=146627)
# (pid=146627) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146627)   import geopandas as gpd  # noqa: E402
# (wrapped_fn pid=143029) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=143029)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (pid=146689) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146689)
# (pid=146689) import os
# (pid=146689) os.environ['USE_PYGEOS'] = '0'
# (pid=146689) import geopandas
# (pid=146689)
# (pid=146689) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146689)   import geopandas as gpd  # noqa: E402
# Ray objects:  13%|█▎        | 4/31 [03:00<13:54, 30.91s/it]   (pid=146747) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146747)
# (pid=146747) import os
# (pid=146747) os.environ['USE_PYGEOS'] = '0'
# (pid=146747) import geopandas
# (pid=146747)
# (pid=146747) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146747)   import geopandas as gpd  # noqa: E402
# Ray objects:  19%|█▉        | 6/31 [03:02<06:00, 14.43s/it](pid=146801) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146801)
# (pid=146801) import os
# (pid=146801) os.environ['USE_PYGEOS'] = '0'
# (pid=146801) import geopandas
# (pid=146801)
# (pid=146801) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146801)   import geopandas as gpd  # noqa: E402
# (pid=146852) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146852)
# (pid=146852) import os
# (pid=146852) os.environ['USE_PYGEOS'] = '0'
# (pid=146852) import geopandas
# (pid=146852)
# (pid=146852) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146852)   import geopandas as gpd  # noqa: E402
# (wrapped_fn pid=143042) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=143042)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  23%|██▎       | 7/31 [03:04<04:14, 10.61s/it](wrapped_fn pid=143034) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=143034)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  29%|██▉       | 9/31 [03:06<02:02,  5.58s/it](pid=146923) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=146923)
# (pid=146923) import os
# (pid=146923) os.environ['USE_PYGEOS'] = '0'
# (pid=146923) import geopandas
# (pid=146923)
# (pid=146923) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=146923)   import geopandas as gpd  # noqa: E402
# Ray objects:  32%|███▏      | 10/31 [03:06<01:25,  4.06s/it](wrapped_fn pid=143038) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=143038)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146747) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=146747)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146747) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=146747)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=143037) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=143037)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146852) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=146852)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146852) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=146852)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects:  35%|███▌      | 11/31 [03:08<01:05,  3.28s/it](wrapped_fn pid=146801) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=146801)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146801) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=146801)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects:  45%|████▌     | 14/31 [03:10<00:25,  1.52s/it](wrapped_fn pid=146923) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=146923)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=146923) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=146923)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects:  55%|█████▍    | 17/31 [03:15<00:21,  1.52s/it](raylet) [2023-01-10 19:36:00,427 E 142940 142940] (raylet) node_manager.cc:3097: 23 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: c13c5ae2618675f85e6061b0e44e470d93299ff95bd97a443d22dadb, IP: 172.27.104.93) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.27.104.93`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# Ray objects:  71%|███████   | 22/31 [04:22<01:26,  9.67s/it](raylet) [2023-01-10 19:37:00,428 E 142940 142940] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: c13c5ae2618675f85e6061b0e44e470d93299ff95bd97a443d22dadb, IP: 172.27.104.93) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.27.104.93`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# Ray objects: 100%|██████████| 31/31 [04:56<00:00,  9.55s/it]
# 2023-01-10 19:37:33,557 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 31
# 2023-01-10 19:37:33,557 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 31
# 2023-01-10 19:37:33,566 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 0
# 2023-01-10 19:37:33,566 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 0
# 2023-01-10 19:37:33,566 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-01-10 19:37:33,566 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-01-10 19:37:33,583 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.01.10.19.31.56/runner_report.parquet
# 2023-01-10 19:37:33,583 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.01.10.19.31.56/runner_report.parquet
# 2023-01-10 19:37:33,583 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:05:37 [HH:MM:SS]
# 2023-01-10 19:37:33,583 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:05:37 [HH:MM:SS]
# 2023-01-10 19:37:33,675 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-01-10 19:37:33,675 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-01-10 19:37:33,676 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-01-10 19:37:33,676 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-01-10 19:37:33,676 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2023-01-10 19:37:33,676 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|██████████| 5/5 [00:00<00:00,  8.06it/s]
# 2023-01-10 19:37:34,726 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:01 [HH:MM:SS]
# 2023-01-10 19:37:34,726 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:01 [HH:MM:SS]
# 2023-01-10 19:37:34,726 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!
# 2023-01-10 19:37:34,726 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd  # noqa: E402
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from nuplan.planning.script.run_nuboard import main as main_nuboard
#       3 # Run nuBoard
# ----> 4 main_nuboard(cfg)
#
# NameError: name 'cfg' is not defined

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.

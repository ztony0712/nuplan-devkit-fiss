# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir #NOTES /tmp/tutorial_nuplan_framework
EXPERIMENT = 'training_raster_experiment'
LOG_DIR = str(SAVE_DIR / EXPERIMENT)

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
    # 'splitter=nuplan',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {LOG_DIR}
# Out:
#       <iframe id="tensorboard-frame-32d915fd6d603ea5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-32d915fd6d603ea5");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd  # noqa: E402
# Global seed set to 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:33, in env(key, default)
#      32 try:
# ---> 33     return os.environ[key]
#      34 except KeyError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'NUPLAN_MAPS_ROOT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 if hasattr( visitor, "visitConfigValue" ):
# --> 205     return visitor.visitConfigValue(self)
#     206 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#     100 assert ctx.getChildCount() == 2
# --> 101 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     338 if hasattr( visitor, "visitText" ):
# --> 339     return visitor.visitText(self)
#     340 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     124 assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125 return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1029 if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030     return visitor.visitInterpolationResolver(self)
#    1031 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# KeyError: "Environment variable 'NUPLAN_MAPS_ROOT' not found"
#
# During handling of the above exception, another exception occurred:
#
# InterpolationResolutionError              Traceback (most recent call last)
# Cell In[6], line 4
#       1 from nuplan.planning.script.run_training import main as main_train
#       3 # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
# ----> 4 main_train(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_training.py:47, in main(cfg)
#      44 build_logger(cfg)
#      46 # Override configs based on setup, and print config
# ---> 47 update_config_for_training(cfg)
#      49 # Create output storage folder
#      50 build_training_experiment_folder(cfg=cfg)
#
# File ~/nuplan-devkit/nuplan/planning/script/builders/utils/utils_config.py:48, in update_config_for_training(cfg)
#      45     cfg.lightning.trainer.params.precision = 32
#      47 # Save all interpolations and remove keys that were only used for interpolation and have no further use.
# ---> 48 OmegaConf.resolve(cfg)
#      50 # Finalize the configuration and make it non-editable.
#      51 OmegaConf.set_struct(cfg, True)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:786, in OmegaConf.resolve(cfg)
#     780 if not OmegaConf.is_config(cfg):
#     781     # Since this function is mutating the input object in-place, it doesn't make sense to
#     782     # auto-convert the input object to an OmegaConf container
#     783     raise ValueError(
#     784         f"Invalid config type ({type(cfg).__name__}), expected an OmegaConf Container"
#     785     )
# --> 786 omegaconf._impl._resolve(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:25, in _resolve_container_value(cfg, key)
#      23             node._set_value(resolved._value())
#      24 else:
# ---> 25     _resolve(node)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:40, in _resolve(cfg)
#      38 if isinstance(cfg, DictConfig):
#      39     for k in cfg.keys():
# ---> 40         _resolve_container_value(cfg, k)
#      42 elif isinstance(cfg, ListConfig):
#      43     for i in range(len(cfg)):
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/_impl.py:14, in _resolve_container_value(cfg, key)
#      12 if node._is_interpolation():
#      13     try:
# ---> 14         resolved = node._dereference_node()
#      15     except InterpolationToMissingValueError:
#      16         node._set_value(MISSING)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:205, in Node._dereference_node(self)
#     204 def _dereference_node(self) -> "Node":
# --> 205     node = self._dereference_node_impl(throw_on_resolution_failure=True)
#     206     assert node is not None
#     207     return node
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:236, in Node._dereference_node_impl(self, throw_on_resolution_failure, memo)
#     234 assert parent is not None
#     235 key = self._key()
# --> 236 return parent._resolve_interpolation_from_parse_tree(
#     237     parent=parent,
#     238     key=key,
#     239     value=self,
#     240     parse_tree=parse(_get_value(self)),
#     241     throw_on_resolution_failure=throw_on_resolution_failure,
#     242     memo=memo,
#     243 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:482, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     452 """
#     453 Resolve an interpolation.
#     454
#    (...)
#     478     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     479 """
#     481 try:
# --> 482     resolved = self.resolve_parse_tree(
#     483         parse_tree=parse_tree, node=value, key=key, parent=parent, memo=memo
#     484     )
#     485 except InterpolationResolutionError:
#     486     if throw_on_resolution_failure:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:667, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     664     raise
#     665 except Exception as exc:
#     666     # Other kinds of exceptions are wrapped in an `InterpolationResolutionError`.
# --> 667     raise InterpolationResolutionError(
#     668         f"{type(exc).__name__} raised while resolving interpolation: {exc}"
#     669     ).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:662, in Container.resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     656 visitor = GrammarVisitor(
#     657     node_interpolation_callback=node_interpolation_callback,
#     658     resolver_interpolation_callback=resolver_interpolation_callback,
#     659     memo=memo,
#     660 )
#     661 try:
# --> 662     return visitor.visit(parse_tree)
#     663 except InterpolationResolutionError:
#     664     raise
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:205, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     203 def accept(self, visitor:ParseTreeVisitor):
#     204     if hasattr( visitor, "visitConfigValue" ):
# --> 205         return visitor.visitConfigValue(self)
#     206     else:
#     207         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:339, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     337 def accept(self, visitor:ParseTreeVisitor):
#     338     if hasattr( visitor, "visitText" ):
# --> 339         return visitor.visitText(self)
#     340     else:
#     341         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     296     c = ctx.getChild(0)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#     301 return self._unescape(list(ctx.getChildren()))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1030, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1028 def accept(self, visitor:ParseTreeVisitor):
#    1029     if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030         return visitor.visitInterpolationResolver(self)
#    1031     else:
#    1032         return visitor.visitChildren(self)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     176         args.append(val)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:648, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     645 def resolver_interpolation_callback(
#     646     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647 ) -> Any:
# --> 648     return self._evaluate_custom_resolver(
#     649         key=key,
#     650         node=node,
#     651         inter_type=name,
#     652         inter_args=args,
#     653         inter_args_str=args_str,
#     654     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/base.py:591, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     589 if resolver is not None:
#     590     root_node = self._get_root()
# --> 591     return resolver(
#     592         root_node,
#     593         self,
#     594         node,
#     595         inter_args,
#     596         inter_args_str,
#     597     )
#     598 else:
#     599     raise UnsupportedInterpolationType(
#     600         f"Unsupported interpolation type {inter_type}"
#     601     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/omegaconf.py:435, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     432 if pass_root:
#     433     kwargs["_root_"] = config
# --> 435 ret = resolver(*args, **kwargs)
#     437 if use_cache:
#     438     cache[args_str] = ret
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      36     return str(default) if default is not None else None
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# InterpolationResolutionError: KeyError raised while resolving interpolation: "Environment variable 'NUPLAN_MAPS_ROOT' not found"

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook) Figure-> figure in metric_summary_callback.py 19

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-02-12 20:49:23,177 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-12 20:49:23,177 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-12 20:49:23,189 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-02-12 20:49:23,189 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-02-12 20:49:23,284 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-02-12 20:49:23,284 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-02-12 20:49:23,284 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-02-12 20:49:23,284 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-02-12 20:49:26,014 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-02-12 20:49:26,014 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-02-12 20:49:28,338	INFO worker.py:1538 -- Started a local Ray instance.
# 2023-02-12 20:49:29,390 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-02-12 20:49:29,390 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-02-12 20:49:29,393 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-02-12 20:49:29,393 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/2023.02.12.20.49.23
#
# 2023-02-12 20:49:29,394 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/2023.02.12.20.49.23
#
# 2023-02-12 20:49:29,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-02-12 20:49:29,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-02-12 20:49:29,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:49:29,395 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-02-12 20:49:29,405 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-02-12 20:49:29,406 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-02-12 20:49:29,406 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-02-12 20:49:29,406 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-02-12 20:49:29,406 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# Ray objects:   0%|          | 0/24 [00:00<?, ?it/s](pid=447869) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447869)
# (pid=447869) import os
# (pid=447869) os.environ['USE_PYGEOS'] = '0'
# (pid=447869) import geopandas
# (pid=447869)
# (pid=447869) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447869)   import geopandas as gpd  # noqa: E402
# (pid=447880) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447880)
# (pid=447880) import os
# (pid=447880) os.environ['USE_PYGEOS'] = '0'
# (pid=447880) import geopandas
# (pid=447880)
# (pid=447880) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447880)   import geopandas as gpd  # noqa: E402
# (pid=447887) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447887)
# (pid=447887) import os
# (pid=447887) os.environ['USE_PYGEOS'] = '0'
# (pid=447887) import geopandas
# (pid=447887)
# (pid=447887) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447887)   import geopandas as gpd  # noqa: E402
# (pid=447872) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447872)
# (pid=447872) import os
# (pid=447872) os.environ['USE_PYGEOS'] = '0'
# (pid=447872) import geopandas
# (pid=447872)
# (pid=447872) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447872)   import geopandas as gpd  # noqa: E402
# (pid=447881) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447881)
# (pid=447881) import os
# (pid=447881) os.environ['USE_PYGEOS'] = '0'
# (pid=447881) import geopandas
# (pid=447881)
# (pid=447881) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447881)   import geopandas as gpd  # noqa: E402
# (pid=447876) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447876)
# (pid=447876) import os
# (pid=447876) os.environ['USE_PYGEOS'] = '0'
# (pid=447876) import geopandas
# (pid=447876)
# (pid=447876) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447876)   import geopandas as gpd  # noqa: E402
# (pid=447870) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447870)
# (pid=447870) import os
# (pid=447870) os.environ['USE_PYGEOS'] = '0'
# (pid=447870) import geopandas
# (pid=447870)
# (pid=447870) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447870)   import geopandas as gpd  # noqa: E402
# (pid=447868) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447868)
# (pid=447868) import os
# (pid=447868) os.environ['USE_PYGEOS'] = '0'
# (pid=447868) import geopandas
# (pid=447868)
# (pid=447868) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447868)   import geopandas as gpd  # noqa: E402
# (pid=447889) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447889)
# (pid=447889) import os
# (pid=447889) os.environ['USE_PYGEOS'] = '0'
# (pid=447889) import geopandas
# (pid=447889)
# (pid=447889) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447889)   import geopandas as gpd  # noqa: E402
# (pid=447890) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447890)
# (pid=447890) import os
# (pid=447890) os.environ['USE_PYGEOS'] = '0'
# (pid=447890) import geopandas
# (pid=447890)
# (pid=447890) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447890)   import geopandas as gpd  # noqa: E402
# (pid=447885) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447885)
# (pid=447885) import os
# (pid=447885) os.environ['USE_PYGEOS'] = '0'
# (pid=447885) import geopandas
# (pid=447885)
# (pid=447885) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447885)   import geopandas as gpd  # noqa: E402
# (pid=447866) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447866)
# (pid=447866) import os
# (pid=447866) os.environ['USE_PYGEOS'] = '0'
# (pid=447866) import geopandas
# (pid=447866)
# (pid=447866) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447866)   import geopandas as gpd  # noqa: E402
# (pid=447886) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447886)
# (pid=447886) import os
# (pid=447886) os.environ['USE_PYGEOS'] = '0'
# (pid=447886) import geopandas
# (pid=447886)
# (pid=447886) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447886)   import geopandas as gpd  # noqa: E402
# (pid=447874) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447874)
# (pid=447874) import os
# (pid=447874) os.environ['USE_PYGEOS'] = '0'
# (pid=447874) import geopandas
# (pid=447874)
# (pid=447874) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447874)   import geopandas as gpd  # noqa: E402
# (pid=447877) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447877)
# (pid=447877) import os
# (pid=447877) os.environ['USE_PYGEOS'] = '0'
# (pid=447877) import geopandas
# (pid=447877)
# (pid=447877) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447877)   import geopandas as gpd  # noqa: E402
# (pid=447878) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447878)
# (pid=447878) import os
# (pid=447878) os.environ['USE_PYGEOS'] = '0'
# (pid=447878) import geopandas
# (pid=447878)
# (pid=447878) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447878)   import geopandas as gpd  # noqa: E402
# (pid=447882) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447882)
# (pid=447882) import os
# (pid=447882) os.environ['USE_PYGEOS'] = '0'
# (pid=447882) import geopandas
# (pid=447882)
# (pid=447882) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447882)   import geopandas as gpd  # noqa: E402
# (pid=447884) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447884)
# (pid=447884) import os
# (pid=447884) os.environ['USE_PYGEOS'] = '0'
# (pid=447884) import geopandas
# (pid=447884)
# (pid=447884) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447884)   import geopandas as gpd  # noqa: E402
# (pid=447875) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447875)
# (pid=447875) import os
# (pid=447875) os.environ['USE_PYGEOS'] = '0'
# (pid=447875) import geopandas
# (pid=447875)
# (pid=447875) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447875)   import geopandas as gpd  # noqa: E402
# (pid=447871) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447871)
# (pid=447871) import os
# (pid=447871) os.environ['USE_PYGEOS'] = '0'
# (pid=447871) import geopandas
# (pid=447871)
# (pid=447871) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447871)   import geopandas as gpd  # noqa: E402
# (pid=447879) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447879)
# (pid=447879) import os
# (pid=447879) os.environ['USE_PYGEOS'] = '0'
# (pid=447879) import geopandas
# (pid=447879)
# (pid=447879) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447879)   import geopandas as gpd  # noqa: E402
# (pid=447867) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447867)
# (pid=447867) import os
# (pid=447867) os.environ['USE_PYGEOS'] = '0'
# (pid=447867) import geopandas
# (pid=447867)
# (pid=447867) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447867)   import geopandas as gpd  # noqa: E402
# (pid=447888) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447888)
# (pid=447888) import os
# (pid=447888) os.environ['USE_PYGEOS'] = '0'
# (pid=447888) import geopandas
# (pid=447888)
# (pid=447888) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447888)   import geopandas as gpd  # noqa: E402
# (pid=447873) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=447873)
# (pid=447873) import os
# (pid=447873) os.environ['USE_PYGEOS'] = '0'
# (pid=447873) import geopandas
# (pid=447873)
# (pid=447873) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=447873)   import geopandas as gpd  # noqa: E402
# Ray objects: 100%|██████████| 24/24 [00:02<00:00,  9.72it/s]
# 2023-02-12 20:49:31,895 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-02-12 20:49:31,895 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-02-12 20:49:31,895 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-02-12 20:49:31,895 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-02-12 20:49:31,921 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-02-12 20:49:31,921 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-02-12 20:49:31,921 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-02-12 20:49:31,921 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:118}  Building simulations...DONE!
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:118}  Building simulations...DONE!
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Running simulation...
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Running simulation...
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:135}  Executing runners...
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:135}  Executing runners...
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:89}  Starting 31 simulations using RayDistributed!
# 2023-02-12 20:49:32,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:89}  Starting 31 simulations using RayDistributed!
# Ray objects:   3%|▎         | 1/31 [00:01<00:36,  1.22s/it](wrapped_fn pid=447881) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447881) Traceback (most recent call last):
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447881)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447881)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=447881)     raise e
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=447881)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=447881)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=447881)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=447881)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=447881)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=447881)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=447881) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447881) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=447881)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447881) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=447881) Failed simulation [log,token]:
# (wrapped_fn pid=447881)  [2021.07.24.23.50.16_veh-17_01696_02071, 1a2a7e17b63e561f]
# (wrapped_fn pid=447881)
# (wrapped_fn pid=447881) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!
# Ray objects:  10%|▉         | 3/31 [00:01<00:09,  2.82it/s](wrapped_fn pid=447889) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447889) Traceback (most recent call last):
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447889)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447889)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=447889)     raise e
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=447889)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=447889)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=447889)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=447889)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=447889)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=447889)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=447889) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447889) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=447889)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447889) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=447889) Failed simulation [log,token]:
# (wrapped_fn pid=447889)  [2021.10.06.17.43.07_veh-28_00508_00877, 9a48aa6a1ebd5027]
# (wrapped_fn pid=447889)
# (wrapped_fn pid=447889) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!
# (wrapped_fn pid=447888) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447888) Traceback (most recent call last):
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447888)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447888)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=447888)     raise e
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=447888)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=447888)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=447888)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=447888)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=447888)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=447888)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=447888) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447888) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=447888)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447888) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=447888) Failed simulation [log,token]:
# (wrapped_fn pid=447888)  [2021.05.12.22.28.35_veh-35_00620_01164, 92a9e6e2b7df5ee7]
# (wrapped_fn pid=447888)
# (wrapped_fn pid=447888) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!
# (wrapped_fn pid=447873) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447873) Traceback (most recent call last):
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447873)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447873)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=447873)     raise e
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=447873)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=447873)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=447873)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=447873)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=447873)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=447873)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=447873) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447873) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=447873)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447873) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=447873) Failed simulation [log,token]:
# (wrapped_fn pid=447873)  [2021.08.17.16.57.11_veh-08_01200_01636, 6088036cf6d15e1c]
# (wrapped_fn pid=447873)
# (wrapped_fn pid=447873) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!
# (pid=450423) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=450423)
# (pid=450423) import os
# (pid=450423) os.environ['USE_PYGEOS'] = '0'
# (pid=450423) import geopandas
# (pid=450423)
# (pid=450423) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=450423)   import geopandas as gpd  # noqa: E402
# (pid=450420) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=450420)
# (pid=450420) import os
# (pid=450420) os.environ['USE_PYGEOS'] = '0'
# (pid=450420) import geopandas
# (pid=450420)
# (pid=450420) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=450420)   import geopandas as gpd  # noqa: E402
# Ray objects:  16%|█▌        | 5/31 [00:01<00:06,  4.12it/s](wrapped_fn pid=447871) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447871) Traceback (most recent call last):
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447871)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447871)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=447871)     raise e
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=447871)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=447871)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=447871)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=447871)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=447871)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=447871)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=447871) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447871) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=447871)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=447871) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=447871) Failed simulation [log,token]:
# (wrapped_fn pid=447871)  [2021.07.09.20.59.12_veh-38_01208_01692, 64d664d5d8ca552c]
# (wrapped_fn pid=447871)
# (wrapped_fn pid=447871) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!
# (pid=450418) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=450418)
# (pid=450418) import os
# (pid=450418) os.environ['USE_PYGEOS'] = '0'
# (pid=450418) import geopandas
# (pid=450418)
# (pid=450418) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=450418)   import geopandas as gpd  # noqa: E402
# Ray objects:  19%|█▉        | 6/31 [00:01<00:05,  4.50it/s](wrapped_fn pid=447886) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=447886) Traceback (most recent call last):
# (wrapped_fn pid=447886)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=447886)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=447886)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=447886)     trajectories = self.planner.compute_trajectory(planner_inputs)
# ...
#     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
#   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
#     self.array = np.array([self.x, self.y], dtype=np.float64)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# '
# 2023-02-12 20:49:35,082 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:130}  Failed Simulation.
#  'Traceback (most recent call last):
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()  # type: ignore
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
#     trajectories = self.planner.compute_trajectory(planner_inputs)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
#     raise e
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
#     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
#     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
#     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
#   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
#     self.array = np.array([self.x, self.y], dtype=np.float64)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# '
# 2023-02-12 20:49:35,082 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:130}  Failed Simulation.
#  'Traceback (most recent call last):
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()  # type: ignore
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
#     trajectories = self.planner.compute_trajectory(planner_inputs)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
#     raise e
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
#     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
#     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
#     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
#   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
#     self.array = np.array([self.x, self.y], dtype=np.float64)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# '
# 2023-02-12 20:49:35,082 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:130}  Failed Simulation.
#  'Traceback (most recent call last):
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()  # type: ignore
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
#     trajectories = self.planner.compute_trajectory(planner_inputs)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
#     raise e
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
#     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
#     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
#   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
#     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
#   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
#     self.array = np.array([self.x, self.y], dtype=np.float64)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# '
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 0
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 0
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 31
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 31
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:139}  Failed simulations [log, token]:
# [2021.06.14.16.48.02_veh-12_04978_05337, 143076200fec5eb1]
# [2021.10.06.17.43.07_veh-28_00508_00877, 18c5655716415505]
# [2021.07.24.23.50.16_veh-17_01696_02071, 1a2a7e17b63e561f]
# [2021.06.08.14.35.24_veh-26_02555_03004, 1f151e15c9cf5c81]
# [2021.06.14.16.48.02_veh-12_04057_04438, 2b713f6a72c359e4]
# [2021.06.07.18.53.26_veh-26_00005_00427, 3318937ef0c65127]
# [2021.06.28.16.29.11_veh-38_01415_01821, 341d564804035105]
# [2021.06.09.14.03.17_veh-12_02584_02970, 3697f140d7b6597d]
# [2021.10.05.07.10.04_veh-52_01442_01802, 40cef783435759d3]
# [2021.06.14.16.32.09_veh-35_05038_05402, 48c1c56182f05317]
# [2021.10.01.19.16.42_veh-28_02011_02410, 51bc179bf27657d8]
# [2021.07.24.23.50.16_veh-17_01696_02071, 56f0fe1e7150539f]
# [2021.08.17.16.57.11_veh-08_01200_01636, 6088036cf6d15e1c]
# [2021.07.09.20.59.12_veh-38_01208_01692, 64d664d5d8ca552c]
# [2021.07.16.18.19.22_veh-35_00440_00858, 6b6ad8e295fa56db]
# [2021.06.09.17.23.18_veh-38_02526_03027, 7a571973ecfa50b7]
# [2021.08.17.18.54.02_veh-45_00665_01065, 7ff1de6b23035dc8]
# [2021.05.12.22.28.35_veh-35_00620_01164, 92a9e6e2b7df5ee7]
# [2021.06.23.17.31.36_veh-16_00016_00377, 94de94cabb8f59b0]
# [2021.10.06.17.43.07_veh-28_00508_00877, 9a48aa6a1ebd5027]
# [2021.06.09.12.39.51_veh-26_01943_02303, 9d7641f22b415ac3]
# [2021.06.09.17.23.18_veh-38_00773_01140, 9f15846eb3d950cb]
# [2021.08.17.17.17.01_veh-45_02314_02798, a3aa215527dd5433]
# [2021.07.09.20.59.12_veh-38_01208_01692, bd93ed4bd08b5115]
# [2021.10.01.19.16.42_veh-28_02011_02410, be051cec36545b3d]
# [2021.06.09.14.58.55_veh-35_01894_02311, c6c1e1aff69b5d12]
# [2021.07.24.20.37.45_veh-17_00015_00375, d9ee9cf40a84520f]
# [2021.07.09.17.06.37_veh-35_00258_00748, dec95bc24abe545e]
# [2021.06.28.16.29.11_veh-38_03263_03766, e1af9cd1265f5a00]
# [2021.10.01.19.16.42_veh-28_02011_02410, e2282a80e62b5df4]
# [2021.06.07.18.53.26_veh-26_00005_00427, ee737ddbbd0458b1]
#
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:139}  Failed simulations [log, token]:
# [2021.06.14.16.48.02_veh-12_04978_05337, 143076200fec5eb1]
# [2021.10.06.17.43.07_veh-28_00508_00877, 18c5655716415505]
# [2021.07.24.23.50.16_veh-17_01696_02071, 1a2a7e17b63e561f]
# [2021.06.08.14.35.24_veh-26_02555_03004, 1f151e15c9cf5c81]
# [2021.06.14.16.48.02_veh-12_04057_04438, 2b713f6a72c359e4]
# [2021.06.07.18.53.26_veh-26_00005_00427, 3318937ef0c65127]
# [2021.06.28.16.29.11_veh-38_01415_01821, 341d564804035105]
# [2021.06.09.14.03.17_veh-12_02584_02970, 3697f140d7b6597d]
# [2021.10.05.07.10.04_veh-52_01442_01802, 40cef783435759d3]
# [2021.06.14.16.32.09_veh-35_05038_05402, 48c1c56182f05317]
# [2021.10.01.19.16.42_veh-28_02011_02410, 51bc179bf27657d8]
# [2021.07.24.23.50.16_veh-17_01696_02071, 56f0fe1e7150539f]
# [2021.08.17.16.57.11_veh-08_01200_01636, 6088036cf6d15e1c]
# [2021.07.09.20.59.12_veh-38_01208_01692, 64d664d5d8ca552c]
# [2021.07.16.18.19.22_veh-35_00440_00858, 6b6ad8e295fa56db]
# [2021.06.09.17.23.18_veh-38_02526_03027, 7a571973ecfa50b7]
# [2021.08.17.18.54.02_veh-45_00665_01065, 7ff1de6b23035dc8]
# [2021.05.12.22.28.35_veh-35_00620_01164, 92a9e6e2b7df5ee7]
# [2021.06.23.17.31.36_veh-16_00016_00377, 94de94cabb8f59b0]
# [2021.10.06.17.43.07_veh-28_00508_00877, 9a48aa6a1ebd5027]
# [2021.06.09.12.39.51_veh-26_01943_02303, 9d7641f22b415ac3]
# [2021.06.09.17.23.18_veh-38_00773_01140, 9f15846eb3d950cb]
# [2021.08.17.17.17.01_veh-45_02314_02798, a3aa215527dd5433]
# [2021.07.09.20.59.12_veh-38_01208_01692, bd93ed4bd08b5115]
# [2021.10.01.19.16.42_veh-28_02011_02410, be051cec36545b3d]
# [2021.06.09.14.58.55_veh-35_01894_02311, c6c1e1aff69b5d12]
# [2021.07.24.20.37.45_veh-17_00015_00375, d9ee9cf40a84520f]
# [2021.07.09.17.06.37_veh-35_00258_00748, dec95bc24abe545e]
# [2021.06.28.16.29.11_veh-38_03263_03766, e1af9cd1265f5a00]
# [2021.10.01.19.16.42_veh-28_02011_02410, e2282a80e62b5df4]
# [2021.06.07.18.53.26_veh-26_00005_00427, ee737ddbbd0458b1]
#
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-02-12 20:49:35,082 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/2023.02.12.20.49.23/runner_report.parquet
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/2023.02.12.20.49.23/runner_report.parquet
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:11 [HH:MM:SS]
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:11 [HH:MM:SS]
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:49:35,085 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-02-12 20:49:35,085 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:49:35,085 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 0it [00:00, ?it/s]
# 2023-02-12 20:49:35,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:49:35,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:49:35,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!
# 2023-02-12 20:49:35,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!
# (wrapped_fn pid=450421) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed: with the following trace:
# (wrapped_fn pid=450421) Traceback (most recent call last):
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
# (wrapped_fn pid=450421)     return sim_runner.run()  # type: ignore
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 134, in run
# (wrapped_fn pid=450421)     trajectories = self.planner.compute_trajectory(planner_inputs)
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 124, in compute_trajectory
# (wrapped_fn pid=450421)     raise e
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 121, in compute_trajectory
# (wrapped_fn pid=450421)     trajectory = self.compute_planner_trajectory(current_input)
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/planner/simple_planner.py", line 98, in compute_planner_trajectory
# (wrapped_fn pid=450421)     state = self.motion_model.propagate_state(state, state.dynamic_car_state, self.sampling_time)
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 98, in propagate_state
# (wrapped_fn pid=450421)     propagating_state = self._update_commands(state, ideal_dynamic_state, sampling_time)
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/planning/simulation/controller/motion_model/kinematic_bicycle.py", line 82, in _update_commands
# (wrapped_fn pid=450421)     rear_axle_acceleration_2d=StateVector2D(updated_accel, 0),
# (wrapped_fn pid=450421)   File "/home/arc/nuplan-devkit/nuplan/common/actor_state/state_representation.py", line 292, in __init__
# (wrapped_fn pid=450421)     self.array = np.array([self.x, self.y], dtype=np.float64)
# (wrapped_fn pid=450421) ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=450421) WARNING:nuplan.planning.simulation.runner.executor:Simulation failed with error:
# (wrapped_fn pid=450421)  setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# (wrapped_fn pid=450421) WARNING:nuplan.planning.simulation.runner.executor:
# (wrapped_fn pid=450421) Failed simulation [log,token]:
# (wrapped_fn pid=450421)  [2021.06.07.18.53.26_veh-26_00005_00427, ee737ddbbd0458b1]
# (wrapped_fn pid=450421)
# (wrapped_fn pid=450421) WARNING:nuplan.planning.simulation.runner.executor:----------- Simulation failed!

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(Path(LOG_DIR).iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-02-12 20:50:02,542 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-12 20:50:02,542 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-02-12 20:50:02,554 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-02-12 20:50:02,554 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-02-12 20:50:02,649 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-02-12 20:50:02,649 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-02-12 20:50:02,649 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-02-12 20:50:02,649 WARNING {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:129}  Ray is running, we will shut it down before starting again!
# 2023-02-12 20:50:05,184 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-02-12 20:50:05,184 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-02-12 20:50:07,478	INFO worker.py:1538 -- Started a local Ray instance.
# 2023-02-12 20:50:08,527 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-02-12 20:50:08,527 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-02-12 20:50:08,529 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-02-12 20:50:08,529 INFO {/home/arc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 24
# Number of GPUs per node: 1
# Number of threads across all nodes: 24
# 2023-02-12 20:50:08,530 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-02-12 20:50:08,530 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-02-12 20:50:08,531 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-02-12 20:50:08,531 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-02-12 20:50:08,531 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.02.12.20.50.02
#
# 2023-02-12 20:50:08,531 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.02.12.20.50.02
#
# 2023-02-12 20:50:08,532 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-02-12 20:50:08,532 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-02-12 20:50:08,532 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:50:08,532 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:69}  Building AbstractCallback: 0...DONE!
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-02-12 20:50:08,547 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-02-12 20:50:08,548 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# Ray objects:   0%|          | 0/24 [00:00<?, ?it/s](pid=451338) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451338)
# (pid=451338) import os
# (pid=451338) os.environ['USE_PYGEOS'] = '0'
# (pid=451338) import geopandas
# (pid=451338)
# (pid=451338) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451338)   import geopandas as gpd  # noqa: E402
# (pid=451347) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451347)
# (pid=451347) import os
# (pid=451347) os.environ['USE_PYGEOS'] = '0'
# (pid=451347) import geopandas
# (pid=451347)
# (pid=451347) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451347)   import geopandas as gpd  # noqa: E402
# (pid=451337) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451337)
# (pid=451337) import os
# (pid=451337) os.environ['USE_PYGEOS'] = '0'
# (pid=451337) import geopandas
# (pid=451337)
# (pid=451337) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451337)   import geopandas as gpd  # noqa: E402
# (pid=451332) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451332)
# (pid=451332) import os
# (pid=451332) os.environ['USE_PYGEOS'] = '0'
# (pid=451332) import geopandas
# (pid=451332)
# (pid=451332) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451332)   import geopandas as gpd  # noqa: E402
# (pid=451348) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451348)
# (pid=451348) import os
# (pid=451348) os.environ['USE_PYGEOS'] = '0'
# (pid=451348) import geopandas
# (pid=451348)
# (pid=451348) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451348)   import geopandas as gpd  # noqa: E402
# (pid=451346) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451346)
# (pid=451346) import os
# (pid=451346) os.environ['USE_PYGEOS'] = '0'
# (pid=451346) import geopandas
# (pid=451346)
# (pid=451346) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451346)   import geopandas as gpd  # noqa: E402
# (pid=451339) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451339)
# (pid=451339) import os
# (pid=451339) os.environ['USE_PYGEOS'] = '0'
# (pid=451339) import geopandas
# (pid=451339)
# (pid=451339) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451339)   import geopandas as gpd  # noqa: E402
# (pid=451345) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451345)
# (pid=451345) import os
# (pid=451345) os.environ['USE_PYGEOS'] = '0'
# (pid=451345) import geopandas
# (pid=451345)
# (pid=451345) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451345)   import geopandas as gpd  # noqa: E402
# (pid=451329) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451329)
# (pid=451329) import os
# (pid=451329) os.environ['USE_PYGEOS'] = '0'
# (pid=451329) import geopandas
# (pid=451329)
# (pid=451329) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451329)   import geopandas as gpd  # noqa: E402
# (pid=451326) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451326)
# (pid=451326) import os
# (pid=451326) os.environ['USE_PYGEOS'] = '0'
# (pid=451326) import geopandas
# (pid=451326)
# (pid=451326) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451326)   import geopandas as gpd  # noqa: E402
# (pid=451333) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451333)
# (pid=451333) import os
# (pid=451333) os.environ['USE_PYGEOS'] = '0'
# (pid=451333) import geopandas
# (pid=451333)
# (pid=451333) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451333)   import geopandas as gpd  # noqa: E402
# (pid=451334) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451334)
# (pid=451334) import os
# (pid=451334) os.environ['USE_PYGEOS'] = '0'
# (pid=451334) import geopandas
# (pid=451334)
# (pid=451334) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451334)   import geopandas as gpd  # noqa: E402
# (pid=451342) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451342)
# (pid=451342) import os
# (pid=451342) os.environ['USE_PYGEOS'] = '0'
# (pid=451342) import geopandas
# (pid=451342)
# (pid=451342) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451342)   import geopandas as gpd  # noqa: E402
# (pid=451327) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451327)
# (pid=451327) import os
# (pid=451327) os.environ['USE_PYGEOS'] = '0'
# (pid=451327) import geopandas
# (pid=451327)
# (pid=451327) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451327)   import geopandas as gpd  # noqa: E402
# (pid=451335) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451335)
# (pid=451335) import os
# (pid=451335) os.environ['USE_PYGEOS'] = '0'
# (pid=451335) import geopandas
# (pid=451335)
# (pid=451335) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451335)   import geopandas as gpd  # noqa: E402
# (pid=451325) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451325)
# (pid=451325) import os
# (pid=451325) os.environ['USE_PYGEOS'] = '0'
# (pid=451325) import geopandas
# (pid=451325)
# (pid=451325) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451325)   import geopandas as gpd  # noqa: E402
# (pid=451336) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451336)
# (pid=451336) import os
# (pid=451336) os.environ['USE_PYGEOS'] = '0'
# (pid=451336) import geopandas
# (pid=451336)
# (pid=451336) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451336)   import geopandas as gpd  # noqa: E402
# (pid=451330) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451330)
# (pid=451330) import os
# (pid=451330) os.environ['USE_PYGEOS'] = '0'
# (pid=451330) import geopandas
# (pid=451330)
# (pid=451330) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451330)   import geopandas as gpd  # noqa: E402
# (pid=451324) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451324)
# (pid=451324) import os
# (pid=451324) os.environ['USE_PYGEOS'] = '0'
# (pid=451324) import geopandas
# (pid=451324)
# (pid=451324) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451324)   import geopandas as gpd  # noqa: E402
# (pid=451331) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451331)
# (pid=451331) import os
# (pid=451331) os.environ['USE_PYGEOS'] = '0'
# (pid=451331) import geopandas
# (pid=451331)
# (pid=451331) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451331)   import geopandas as gpd  # noqa: E402
# (pid=451341) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451341)
# (pid=451341) import os
# (pid=451341) os.environ['USE_PYGEOS'] = '0'
# (pid=451341) import geopandas
# (pid=451341)
# (pid=451341) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451341)   import geopandas as gpd  # noqa: E402
# (pid=451340) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451340)
# (pid=451340) import os
# (pid=451340) os.environ['USE_PYGEOS'] = '0'
# (pid=451340) import geopandas
# (pid=451340)
# (pid=451340) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451340)   import geopandas as gpd  # noqa: E402
# (pid=451344) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451344)
# (pid=451344) import os
# (pid=451344) os.environ['USE_PYGEOS'] = '0'
# (pid=451344) import geopandas
# (pid=451344)
# (pid=451344) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451344)   import geopandas as gpd  # noqa: E402
# (pid=451328) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=451328)
# (pid=451328) import os
# (pid=451328) os.environ['USE_PYGEOS'] = '0'
# (pid=451328) import geopandas
# (pid=451328)
# (pid=451328) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=451328)   import geopandas as gpd  # noqa: E402
# Ray objects: 100%|██████████| 24/24 [00:02<00:00, 10.69it/s]
# 2023-02-12 20:50:10,819 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-02-12 20:50:10,819 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-02-12 20:50:10,819 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-02-12 20:50:10,819 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:10,835 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:10,971 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:10,971 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:11,014 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,014 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,037 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:11,037 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:11,199 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:11,199 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:11,330 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:11,330 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:11,362 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,362 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,379 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:11,379 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:11,698 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:11,698 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:11,816 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:11,816 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:11,841 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,841 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:11,856 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:11,856 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,000 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,117 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,117 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,138 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,138 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,153 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,153 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,481 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,481 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,600 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,600 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,625 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,625 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,643 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,643 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,787 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,787 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:12,905 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,905 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:12,927 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,927 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:12,942 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:12,942 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:13,264 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:13,264 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:13,381 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:13,381 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:13,406 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:13,406 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:13,422 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:13,422 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:13,743 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:13,743 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:13,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:13,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:13,881 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:13,881 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:13,897 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:13,897 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,032 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,032 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,147 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,147 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,173 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,173 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,190 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,190 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,552 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,552 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,669 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,669 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,690 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,690 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,705 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,705 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,840 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,840 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:14,957 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,957 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:14,982 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,982 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:14,997 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:14,997 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:15,344 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:15,344 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:15,465 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:15,465 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:15,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:15,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:15,502 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:15,502 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-02-12 20:50:15,641 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:15,641 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-02-12 20:50:15,760 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:15,760 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-02-12 20:50:15,785 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-02-12 20:50:15,785 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# ...
# (pid=457160)   import geopandas as gpd  # noqa: E402
# 2023-02-12 20:53:34,901	WARNING worker.py:1851 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 3a2119edbd4f6aa1913896034b1582b759d6d7e001000000 Worker ID: 1745cc7b24522a9012b4ea0b4e5ced6ca45c2d6272ccd49d8b3a400a Node ID: 16d98d024a9449ab01bb05645be13ef5a04e20713956e2b5a1ceeb02 Worker IP address: 172.16.175.70 Worker port: 37727 Worker PID: 451327 Worker exit type: SYSTEM_ERROR Worker exit detail: The leased worker has unrecoverable failure. Worker is requested to be destroyed when it is returned.
# (pid=457630) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=457630)
# (pid=457630) import os
# (pid=457630) os.environ['USE_PYGEOS'] = '0'
# (pid=457630) import geopandas
# (pid=457630)
# (pid=457630) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=457630)   import geopandas as gpd  # noqa: E402
# (pid=457631) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=457631)
# (pid=457631) import os
# (pid=457631) os.environ['USE_PYGEOS'] = '0'
# (pid=457631) import geopandas
# (pid=457631)
# (pid=457631) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=457631)   import geopandas as gpd  # noqa: E402
# (pid=457838) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=457838)
# (pid=457838) import os
# (pid=457838) os.environ['USE_PYGEOS'] = '0'
# (pid=457838) import geopandas
# (pid=457838)
# (pid=457838) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=457838)   import geopandas as gpd  # noqa: E402
# (pid=457837) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=457837)
# (pid=457837) import os
# (pid=457837) os.environ['USE_PYGEOS'] = '0'
# (pid=457837) import geopandas
# (pid=457837)
# (pid=457837) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=457837)   import geopandas as gpd  # noqa: E402
# 2023-02-12 20:53:44,089	WARNING worker.py:1851 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: f2c80abfb7451c5e6d33b1cca14434057951cb8301000000 Worker ID: 7b7ba06c8afa3feef368fab7fe2cc91cf93ab6094d4296c60fc1d9d0 Node ID: 16d98d024a9449ab01bb05645be13ef5a04e20713956e2b5a1ceeb02 Worker IP address: 172.16.175.70 Worker port: 35309 Worker PID: 451346 Worker exit type: SYSTEM_ERROR Worker exit detail: The leased worker has unrecoverable failure. Worker is requested to be destroyed when it is returned.
# (wrapped_fn pid=457298) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=457298)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=457298) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=457298)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (pid=458042) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=458042)
# (pid=458042) import os
# (pid=458042) os.environ['USE_PYGEOS'] = '0'
# (pid=458042) import geopandas
# (pid=458042)
# (pid=458042) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=458042)   import geopandas as gpd  # noqa: E402
# (pid=458226) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=458226)
# (pid=458226) import os
# (pid=458226) os.environ['USE_PYGEOS'] = '0'
# (pid=458226) import geopandas
# (pid=458226)
# (pid=458226) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=458226)   import geopandas as gpd  # noqa: E402
# (pid=458225) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=458225)
# (pid=458225) import os
# (pid=458225) os.environ['USE_PYGEOS'] = '0'
# (pid=458225) import geopandas
# (pid=458225)
# (pid=458225) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=458225)   import geopandas as gpd  # noqa: E402
# (pid=458390) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=458390)
# (pid=458390) import os
# (pid=458390) os.environ['USE_PYGEOS'] = '0'
# (pid=458390) import geopandas
# (pid=458390)
# (pid=458390) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=458390)   import geopandas as gpd  # noqa: E402
# Ray objects:   6%|▋         | 2/31 [03:17<39:24, 81.52s/it]   (wrapped_fn pid=457630) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=457630)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  10%|▉         | 3/31 [03:18<20:50, 44.67s/it](wrapped_fn pid=457630) /home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=457630)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects:  16%|█▌        | 5/31 [03:20<07:44, 17.88s/it](pid=458489) /home/arc/nuplan-devkit/nuplan/common/maps/maps_datatypes.py:13: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
# (pid=458489)
# (pid=458489) import os
# (pid=458489) os.environ['USE_PYGEOS'] = '0'
# (pid=458489) import geopandas
# (pid=458489)
# (pid=458489) In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
# (pid=458489)   import geopandas as gpd  # noqa: E402
# Ray objects:  61%|██████▏   | 19/31 [03:25<00:05,  2.09it/s](wrapped_fn pid=451348) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=451348)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=451326) /home/arc/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:429: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=451326)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (raylet) [2023-02-12 20:54:11,856 E 451236 451236] (raylet) node_manager.cc:3097: 20 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 16d98d024a9449ab01bb05645be13ef5a04e20713956e2b5a1ceeb02, IP: 172.16.175.70) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.16.175.70`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# Ray objects: 100%|██████████| 31/31 [04:36<00:00,  8.93s/it]
# 2023-02-12 20:55:08,653 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 31
# 2023-02-12 20:55:08,653 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:134}  Number of successful simulations: 31
# 2023-02-12 20:55:08,654 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 0
# 2023-02-12 20:55:08,654 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:135}  Number of failed simulations: 0
# 2023-02-12 20:55:08,654 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-02-12 20:55:08,654 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-02-12 20:55:08,667 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.02.12.20.50.02/runner_report.parquet
# 2023-02-12 20:55:08,667 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/2023.02.12.20.50.02/runner_report.parquet
# 2023-02-12 20:55:08,667 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:05:06 [HH:MM:SS]
# 2023-02-12 20:55:08,667 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:05:06 [HH:MM:SS]
# 2023-02-12 20:55:08,754 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:55:08,754 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:55:08,755 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-02-12 20:55:08,755 WARNING {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:53}  open_loop_boxes_weighted_average: No metric files found for aggregation!
# 2023-02-12 20:55:08,755 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2023-02-12 20:55:08,755 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|██████████| 5/5 [00:00<00:00,  5.46it/s]
# 2023-02-12 20:55:10,109 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:01 [HH:MM:SS]
# 2023-02-12 20:55:10,109 INFO {/home/arc/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:01 [HH:MM:SS]
# 2023-02-12 20:55:10,109 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!
# 2023-02-12 20:55:10,109 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# 2023-02-12 21:31:47,651 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 21:31:47,651 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 21:31:47,658 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 21:31:47,658 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 21:31:47,659 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:70}  Opening Bokeh application on http://localhost:5006/
# 2023-02-12 21:31:47,659 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:70}  Opening Bokeh application on http://localhost:5006/
# 2023-02-12 21:31:47,659 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/server.py:403}  Starting Bokeh server version 2.4.2 (running on Tornado 6.2)
# 2023-02-12 21:31:47,659 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/server.py:403}  Starting Bokeh server version 2.4.2 (running on Tornado 6.2)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[26], line 4
#       1 from nuplan.planning.script.run_nuboard import main as main_nuboard
#       3 # Run nuBoard
# ----> 4 main_nuboard(cfg)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_nuboard.py:68, in main(cfg)
#      63 """
#      64 Execute all available challenges simultaneously on the same scenario.
#      65 :param cfg: DictConfig. Configuration that is used to run the experiment.
#      66 """
#      67 nuboard = initialize_nuboard(cfg)
# ---> 68 nuboard.run()
#
# File ~/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:85, in NuBoard.run(self)
#      82     self._profiler.start_profiler(self._profiler_file_name)
#      84 bokeh_app = Application(FunctionHandler(self.main_page))
# ---> 85 server = Server(
#      86     {"/": bokeh_app},
#      87     io_loop=io_loop,
#      88     port=self._port_number,
#      89     allow_websocket_origin=["*"],
#      90     extra_patterns=[(r"/resource/(.*)", StaticFileHandler, {"path": str(self._resource_path)})],
#      91 )
#      92 server.start()
#      94 io_loop.add_callback(server.show, "/")
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/server.py:426, in Server.__init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     423     context.load_cert_chain(certfile=opts.ssl_certfile, keyfile=opts.ssl_keyfile, password=opts.ssl_password)
#     424     http_server_kwargs['ssl_options'] = context
# --> 426 sockets, self._port = bind_sockets(opts.address, opts.port)
#     427 self._address = opts.address
#     429 extra_websocket_origins = create_hosts_allowlist(opts.allow_websocket_origin, self.port)
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/util.py:73, in bind_sockets(address, port)
#      53 def bind_sockets(address: str | None, port: int) -> Tuple[List[socket], int]:
#      54     ''' Bind a socket to a port on an address.
#      55
#      56     Args:
#    (...)
#      71
#      72     '''
# ---> 73     ss = netutil.bind_sockets(port=port or 0, address=address)
#      74     assert len(ss)
#      75     ports = {s.getsockname()[1] for s in ss}
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/netutil.py:162, in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     160 sock.setblocking(False)
#     161 try:
# --> 162     sock.bind(sockaddr)
#     163 except OSError as e:
#     164     if (
#     165         errno_from_exception(e) == errno.EADDRNOTAVAIL
#     166         and address == "localhost"
#    (...)
#     178         # might be a real problem like a typo in a
#     179         # configuration.
#
# OSError: [Errno 98] Address already in use
# 2023-02-12 21:32:08,267 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0011 seconds.
# 2023-02-12 21:32:08,267 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0011 seconds.
# 2023-02-12 21:32:08,332 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 118.99ms
# 2023-02-12 21:32:08,332 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 118.99ms
# INFO:tornado.access:200 GET / (::1) 118.99ms
# 2023-02-12 21:32:08,571 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.90ms
# 2023-02-12 21:32:08,571 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.90ms
# 2023-02-12 21:32:08,571 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:32:08,571 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:32:08,572 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:32:08,572 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:101 GET /ws (::1) 0.90ms
# 2023-02-12 21:43:52,802 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0013 seconds.
# 2023-02-12 21:43:52,802 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0013 seconds.
# 2023-02-12 21:43:52,881 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 214.79ms
# 2023-02-12 21:43:52,881 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 214.79ms
# 2023-02-12 21:43:52,893 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:52,893 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# INFO:tornado.access:200 GET / (::1) 214.79ms
# INFO:tornado.access:101 GET /ws (::1) 0.59ms
# 2023-02-12 21:43:53,039 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.59ms
# 2023-02-12 21:43:53,039 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.59ms
# 2023-02-12 21:43:53,040 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:53,040 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:53,040 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:53,040 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:54,112 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0006 seconds.
# 2023-02-12 21:43:54,112 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0006 seconds.
# 2023-02-12 21:43:54,179 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 181.98ms
# 2023-02-12 21:43:54,179 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 181.98ms
# 2023-02-12 21:43:54,186 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:54,186 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# INFO:tornado.access:200 GET / (::1) 181.98ms
# INFO:tornado.access:101 GET /ws (::1) 0.40ms
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.40ms
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.40ms
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:54,347 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:54,514 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:54,514 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:54,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 92.25ms
# 2023-02-12 21:43:54,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 92.25ms
# 2023-02-12 21:43:54,606 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:54,606 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.39ms
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.39ms
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:54,718 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 92.25ms
# INFO:tornado.access:101 GET /ws (::1) 0.39ms
# 2023-02-12 21:43:54,990 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:54,990 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:55,045 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 87.24ms
# 2023-02-12 21:43:55,045 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 87.24ms
# 2023-02-12 21:43:55,051 WARNING {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:287}  Failed sending message as connection was closed
# 2023-02-12 21:43:55,051 WARNING {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:287}  Failed sending message as connection was closed
# 2023-02-12 21:43:55,052 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=None, reason=None
# 2023-02-12 21:43:55,052 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=None, reason=None
# 2023-02-12 21:43:55,163 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.43ms
# 2023-02-12 21:43:55,163 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.43ms
# 2023-02-12 21:43:55,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:55,164 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 87.24ms
# INFO:tornado.access:101 GET /ws (::1) 0.43ms
# 2023-02-12 21:43:55,232 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:55,232 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:55,296 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 102.75ms
# 2023-02-12 21:43:55,296 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 102.75ms
# 2023-02-12 21:43:55,400 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:55,400 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# INFO:tornado.access:200 GET / (::1) 102.75ms
# INFO:tornado.access:101 GET /ws (::1) 0.42ms
# 2023-02-12 21:43:55,486 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.42ms
# 2023-02-12 21:43:55,486 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.42ms
# 2023-02-12 21:43:55,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:55,487 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:55,591 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:55,591 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:43:55,646 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 95.72ms
# 2023-02-12 21:43:55,646 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 95.72ms
# INFO:tornado.access:200 GET / (::1) 95.72ms
# INFO:tornado.access:101 GET /ws (::1) 0.36ms
# 2023-02-12 21:43:55,739 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:55,739 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:43:55,825 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.36ms
# 2023-02-12 21:43:55,825 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.36ms
# 2023-02-12 21:43:55,826 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,826 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:43:55,826 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:55,826 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:43:57,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0190 seconds.
# 2023-02-12 21:43:57,088 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0190 seconds.
# 2023-02-12 21:43:57,728 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0195 seconds.
# 2023-02-12 21:43:57,728 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0195 seconds.
# 2023-02-12 21:43:58,590 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0200 seconds.
# 2023-02-12 21:43:58,590 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0200 seconds.
# 2023-02-12 21:44:02,891 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0176 seconds.
# 2023-02-12 21:44:02,891 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0176 seconds.
# 2023-02-12 21:44:02,901 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0087 seconds.
# 2023-02-12 21:44:02,901 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0087 seconds.
# 2023-02-12 21:44:05,704 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:44:05,704 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:44:05,763 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 176.91ms
# 2023-02-12 21:44:05,763 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 176.91ms
# 2023-02-12 21:44:05,770 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:44:05,770 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:44:05,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.41ms
# 2023-02-12 21:44:05,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.41ms
# 2023-02-12 21:44:05,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:44:05,859 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:44:05,860 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:44:05,860 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 176.91ms
# INFO:tornado.access:101 GET /ws (::1) 0.41ms
# 2023-02-12 21:44:06,098 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:44:06,098 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:44:06,153 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 87.06ms
# 2023-02-12 21:44:06,153 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 87.06ms
# 2023-02-12 21:44:06,159 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:44:06,159 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.37ms
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.37ms
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:44:06,268 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 87.06ms
# INFO:tornado.access:101 GET /ws (::1) 0.37ms
# 2023-02-12 21:44:12,931 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:44:12,931 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1545">Loading BokehJS ...</span>
#     </div>
# 2023-02-12 20:56:17,229 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:56:17,229 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-02-12 20:56:17,236 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:56:17,236 INFO {/home/arc/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-02-12 20:56:17,237 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/server.py:403}  Starting Bokeh server version 2.4.2 (running on Tornado 6.2)
# 2023-02-12 20:56:17,237 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/server.py:403}  Starting Bokeh server version 2.4.2 (running on Tornado 6.2)
# 2023-02-12 20:56:17,237 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/tornado.py:360}  User authentication hooks NOT provided (default user enabled)
# 2023-02-12 20:56:17,237 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/tornado.py:360}  User authentication hooks NOT provided (default user enabled)
# <script id="1546">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:36155/autoload.js?bokeh-autoload-element=1546&bokeh-absolute-url=http://localhost:36155&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# 2023-02-12 20:56:17,380 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 20:56:17,380 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 20:56:17,430 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET /autoload.js?bokeh-autoload-element=1546&bokeh-absolute-url=http://localhost:36155&resources=none (::1) 95.88ms
# 2023-02-12 20:56:17,430 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET /autoload.js?bokeh-autoload-element=1546&bokeh-absolute-url=http://localhost:36155&resources=none (::1) 95.88ms
# 2023-02-12 20:56:17,437 ERROR {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:119}  Refusing websocket connection from Origin 'vscode-webview://10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg';                       use --allow-websocket-origin=10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg or set BOKEH_ALLOW_WS_ORIGIN=10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg to permit this; currently we allow origins {'localhost:8888'}
# 2023-02-12 20:56:17,437 ERROR {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:119}  Refusing websocket connection from Origin 'vscode-webview://10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg';                       use --allow-websocket-origin=10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg or set BOKEH_ALLOW_WS_ORIGIN=10fugokatp768ovmfa85t26glu51n51bo5nde4h94lirkppvodsg to permit this; currently we allow origins {'localhost:8888'}
# 2023-02-12 20:56:17,437 WARNING {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  403 GET /ws?id=0798ce41-24d3-44e9-a3b9-d69496aa1a9f&origin=78b3167f-3300-4dbc-8f1b-188af505bf3f&swVersion=4&extensionId=&platform=electron&vscode-resource-base-authority=vscode-resource.vscode-cdn.net&parentOrigin=vscode-file%3A%2F%2Fvscode-app&purpose=notebookRenderer (::1) 0.84ms
# 2023-02-12 20:56:17,437 WARNING {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  403 GET /ws?id=0798ce41-24d3-44e9-a3b9-d69496aa1a9f&origin=78b3167f-3300-4dbc-8f1b-188af505bf3f&swVersion=4&extensionId=&platform=electron&vscode-resource-base-authority=vscode-resource.vscode-cdn.net&parentOrigin=vscode-file%3A%2F%2Fvscode-app&purpose=notebookRenderer (::1) 0.84ms
# INFO:tornado.access:200 GET /autoload.js?bokeh-autoload-element=1546&bokeh-absolute-url=http://localhost:36155&resources=none (::1) 95.88ms
# WARNING:tornado.access:403 GET /ws?id=0798ce41-24d3-44e9-a3b9-d69496aa1a9f&origin=78b3167f-3300-4dbc-8f1b-188af505bf3f&swVersion=4&extensionId=&platform=electron&vscode-resource-base-authority=vscode-resource.vscode-cdn.net&parentOrigin=vscode-file%3A%2F%2Fvscode-app&purpose=notebookRenderer (::1) 0.84ms
# 2023-02-12 20:56:29,209 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0006 seconds.
# 2023-02-12 20:56:29,209 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0006 seconds.
# 2023-02-12 20:56:29,269 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 217.55ms
# 2023-02-12 20:56:29,269 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 217.55ms
# 2023-02-12 20:56:29,275 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 20:56:29,275 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# INFO:tornado.access:200 GET / (::1) 217.55ms
# INFO:tornado.access:101 GET /ws (::1) 0.40ms
# 2023-02-12 20:56:29,448 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.40ms
# 2023-02-12 20:56:29,448 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.40ms
# 2023-02-12 20:56:29,448 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 20:56:29,448 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 20:56:29,449 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 20:56:29,449 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 20:59:15,127 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0176 seconds.
# 2023-02-12 20:59:15,127 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0176 seconds.
# 2023-02-12 20:59:25,930 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0250 seconds.
# 2023-02-12 20:59:25,930 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0250 seconds.
# 2023-02-12 20:59:26,785 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0188 seconds.
# 2023-02-12 20:59:26,785 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0188 seconds.
# 2023-02-12 21:02:29,558 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0150 seconds.
# 2023-02-12 21:02:29,558 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0150 seconds.
# 2023-02-12 21:02:29,567 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0078 seconds.
# 2023-02-12 21:02:29,567 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0078 seconds.
# 2023-02-12 21:02:38,338 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0206 seconds.
# 2023-02-12 21:02:38,338 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0206 seconds.
# 2023-02-12 21:02:39,079 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0249 seconds.
# 2023-02-12 21:02:39,079 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0249 seconds.
# 2023-02-12 21:02:40,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0009 seconds.
# 2023-02-12 21:02:40,358 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0009 seconds.
# 2023-02-12 21:02:40,416 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 162.21ms
# 2023-02-12 21:02:40,416 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 162.21ms
# 2023-02-12 21:02:40,422 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:40,422 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# INFO:tornado.access:200 GET / (::1) 162.21ms
# INFO:tornado.access:101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:40,568 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:40,568 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:40,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:40,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:40,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:02:40,569 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:02:41,271 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:02:41,271 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:02:41,332 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 132.26ms
# 2023-02-12 21:02:41,332 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 132.26ms
# 2023-02-12 21:02:41,338 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:41,338 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:41,422 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.39ms
# 2023-02-12 21:02:41,422 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.39ms
# 2023-02-12 21:02:41,423 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:41,423 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:41,423 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:02:41,423 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 132.26ms
# INFO:tornado.access:101 GET /ws (::1) 0.39ms
# 2023-02-12 21:02:41,945 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:02:41,945 INFO {/home/arc/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:479}  Rending scenario plot takes 0.0005 seconds.
# 2023-02-12 21:02:42,006 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 154.82ms
# 2023-02-12 21:02:42,006 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (::1) 154.82ms
# 2023-02-12 21:02:42,011 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:42,011 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:132}  WebSocket connection opened
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# 2023-02-12 21:02:42,097 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:213}  ServerConnection created
# INFO:tornado.access:200 GET / (::1) 154.82ms
# INFO:tornado.access:101 GET /ws (::1) 0.56ms
# 2023-02-12 21:02:42,865 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None
# 2023-02-12 21:02:42,865 INFO {/home/arc/anaconda3/envs/nuplan/lib/python3.9/site-packages/bokeh/server/views/ws.py:306}  WebSocket connection closed: code=1001, reason=None

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
